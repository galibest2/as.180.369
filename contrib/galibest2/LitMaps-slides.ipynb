# %% [markdown]
# # LitMaps
# *Tool utilization from initial search to expanded source network*

# %% [markdown]
# # Inital search
#
# *Foundation for understanding the topic*

# %% [markdown]
# This initial search was looking simply at the relationship between immigration and labor force participation
#
# ![image.png](attachment:01d8236a-ca90-4f7f-96b8-a330119bce3e.png)

# %% [markdown]
# From a broader search, the sources became focused on the following
#
# ![image.png](attachment:77ab9f20-b0a5-4903-9391-3bec466e6d27.png)

# %% [markdown]
# # Second search
#
# *Foundation of the first draft*

# %% [markdown]
# This search connected the relationship between immigration and labor force participation alongside the media's involvement
#
# ![image.png](attachment:01817ac4-7214-44c4-b651-3c619e22d171.png)

# %% [markdown]
# # Expansion of search
#
# *New texts that could help with interpretation and organization of data*

# %% [markdown]
# This search was created using the previous data as a seed
#
# ![image.png](attachment:6360a0a5-eecf-4814-9680-719a1a0316aa.png)

# %% [markdown]
# The following map consists of sources from multiple stages
#
# ![image.png](attachment:feddf56b-5095-4a76-81f2-88fa6f9d6d32.png)
